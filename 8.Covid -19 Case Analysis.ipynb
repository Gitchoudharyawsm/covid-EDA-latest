# %%
# Importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
# Reading dataset

# %% [markdown]
# #loading the dataset

# %%
df
# Loading dataset
# Out:
#       sno                                state_name  active   positive  \
# 0       2               Andaman and Nicobar Islands       7       7573
# 1       1                            Andhra Pradesh   14452    2023242
# 2       3                         Arunachal Pradesh     611      53474
# 3       4                                     Assam    6457     593087
# 4       5                                     Bihar      55     725765
# 5       6                                Chandigarh      34      65124
# 6       7                              Chhattisgarh     364    1004724
# 7       8  Dadra and Nagar Haveli and Daman and Diu       2      10665
# 8      10                                     Delhi     386    1438041
# 9      11                                       Goa     854     174560
# 10     12                                   Gujarat     149     825527
# 11     13                                   Haryana     622     770584
# 12     14                          Himachal Pradesh    1682     214911
# 13     15                         Jammu and Kashmir    1264     326159
# 14     16                                 Jharkhand     129     347989
# 15     17                                 Karnataka   17458    2956988
# 16     18                                    Kerala  237601    4253298
# 17     19                                    Ladakh      48      20593
# 18     20                               Lakshadweep       4      10348
# 19     21                            Madhya Pradesh     127     792281
# 20     22                               Maharashtra   51465    6493698
# 21     23                                   Manipur    3168     115866
# 22     24                                 Meghalaya    1924      77275
# 23     25                                   Mizoram   11986      66910
# 24     26                                  Nagaland     709      30435
# 25     27                                    Odisha    6152    1012805
# 26     28                                Puducherry     974     124311
# 27     29                                    Punjab     320     600877
# 28     30                                 Rajasthan      80     954149
# 29     31                                    Sikkim     859      30330
# 30     32                                Tamil Nadu   16205    2625778
# 31     34                                 Telangana    5476     660142
# 32     33                                   Tripura     647      83414
# 33     35                               Uttarakhand     371     343139
# 34     36                             Uttar Pradesh     227    1709479
# 35     37                               West Bengal    8387    1553177
# 36  11111                                            391256  330596718
#
#        cured   death  new_active  new_positive  new_cured  new_death  \
# 0       7437     129           9          7576       7438        129
# 1    1994855   13935       14510       2024603    1996143      13950
# 2      52595     268         617         53551      52665        269
# 3     580911    5719        6298        593514     581493       5723
# 4     716054    9656          65        725784     716062       9657
# 5      64275     815          31         65138      64292        815
# 6     990803   13557         390       1004772     990825      13557
# 7      10659       4           6         10669      10659          4
# 8    1412572   25083         414       1438082    1412585      25083
# 9     170496    3210         856        174646     170578       3212
# 10    815296   10082         151        825544     815311      10082
# 11    760276    9686         607        770601     760308       9686
# 12    209611    3618        1703        215074     209749       3622
# 13    320485    4410        1251        326310     320648       4411
# 14    342727    5133         139        348012     342740       5133
# 15   2902089   37441       17085       2958090    2903547      37458
# 16   3993877   21820      240037       4283494    4021456      22001
# 17     20338     207          39         20593      20347        207
# 18     10293      51           2         10349      10296         51
# 19    781638   10516         137        792297     781644      10516
# 20   6304336  137897       51419       6497872    6308491     137962
# 21    110896    1802        3164        116134     111165       1805
# 22     74016    1335        1888         77471      74246       1337
# 23     54697     227       12304         67971      55438        229
# 24     29094     632         707         30485      29144        634
# 25    998591    8062        6332       1013567     999165       8070
# 26    121518    1819         986        124436     121631       1819
# 27    584110   16447         319        600914     584146      16449
# 28    945115    8954          82        954161     945125       8954
# 29     29095     376         862         30384      29146        376
# 30   2574518   35055       16180       2627365    2576112      35073
# 31    650778    3888        5497        660471     651085       3889
# 32     81964     803         676         83478      81999        803
# 33    335379    7389         349        343151     335413       7389
# 34   1686389   22863         214       1709494    1686417      22863
# 35   1526268   18522        8288       1553928    1527109      18531
# 36  32264051  441411      393614      33139981   32304618     441749
#
#    state_code
# 0          35
# 1          28
# 2          12
# 3          18
# 4          10
# 5          04
# 6          22
# 7          26
# 8          07
# 9          30
# 10         24
# 11         06
# 12         02
# 13         01
# 14         20
# 15         29
# 16         32
# 17         37
# 18         31
# 19         23
# 20         27
# 21         14
# 22         17
# 23         15
# 24         13
# 25         21
# 26         34
# 27         03
# 28         08
# 29         11
# 30         33
# 31         36
# 32         16
# 33         05
# 34         09
# 35         19
# 36

# %% [markdown]
# ### DataUnderstanding

# %%
df.shape
# There are 37 rows and 11 columns
# Out:
# (37, 11)

# %%
df.isnull().sum()
# no null values
# Out:
# sno             0
# state_name      0
# active          0
# positive        0
# cured           0
# death           0
# new_active      0
# new_positive    0
# new_cured       0
# new_death       0
# state_code      0
# dtype: int64

# %%
df.info()
# type of data present in the columns(int,object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sno           37 non-null     int64
#  1   state_name    37 non-null     object
#  2   active        37 non-null     int64
#  3   positive      37 non-null     int64
#  4   cured         37 non-null     int64
#  5   death         37 non-null     int64
#  6   new_active    37 non-null     int64
#  7   new_positive  37 non-null     int64
#  8   new_cured     37 non-null     int64
#  9   new_death     37 non-null     int64
#  10  state_code    37 non-null     object
# dtypes: int64(9), object(2)
# memory usage: 3.3+ KB

# %%
df.describe()
# Viewing the descriptive statistics of the data like mean, std deviation, min and max values present in the dataset
# Out:
#                 sno         active      positive         cured          death  \
# count     37.000000      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean     319.054054   21148.972973  9.829552e+06  1.744003e+06   23860.054054
# std     1823.499245   73928.924873  5.421501e+07  5.315397e+06   74306.372019
# min        1.000000       2.000000  7.573000e+03  7.437000e+03       4.000000
# 25%       11.000000     149.000000  7.727500e+04  7.401600e+04     815.000000
# 50%       20.000000     709.000000  5.930870e+05  5.809110e+05    5719.000000
# 75%       29.000000    6152.000000  1.012805e+06  9.985910e+05   13935.000000
# max    11111.000000  391256.000000  3.305967e+08  3.226405e+07  441411.000000
#
#           new_active  new_positive     new_cured      new_death
# count      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean    21276.432432  1.791350e+06  1.746196e+06   23878.324324
# std     74453.826031  5.462653e+06  5.322283e+06   74361.626604
# min         2.000000  7.576000e+03  7.438000e+03       4.000000
# 25%       151.000000  7.747100e+04  7.424600e+04     815.000000
# 50%       707.000000  5.935140e+05  5.814930e+05    5723.000000
# 75%      6298.000000  1.013567e+06  9.991650e+05   13950.000000
# max    393614.000000  3.313998e+07  3.230462e+07  441749.000000

# %%
df.keys()
# Displaying all the column names present in data
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
df.columns
# Different code but same purpose as above that is displaying all column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# The nunique() function is used to count distinct observations over requested axis. It returns Series with number of distinct observations.
# Out:
# sno             37
# state_name      37
# active          37
# positive        37
# cured           37
# death           37
# new_active      37
# new_positive    37
# new_cured       37
# new_death       37
# state_code      37
# dtype: int64

# %%
df.tail()
# As we can see there is an extra row in the end that may be the total of that column
# Out:
#       sno     state_name  active   positive     cured   death  new_active  \
# 32     33        Tripura     647      83414     81964     803         676
# 33     35    Uttarakhand     371     343139    335379    7389         349
# 34     36  Uttar Pradesh     227    1709479   1686389   22863         214
# 35     37    West Bengal    8387    1553177   1526268   18522        8288
# 36  11111                 391256  330596718  32264051  441411      393614
#
#     new_positive  new_cured  new_death state_code
# 32         83478      81999        803         16
# 33        343151     335413       7389         05
# 34       1709494    1686417      22863         09
# 35       1553928    1527109      18531         19
# 36      33139981   32304618     441749

# %%
df=df.iloc[:36]
# we apply the iloc function and select all rows except the last row

# %%
df
# This is the dataset that we are to work on
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     2               Andaman and Nicobar Islands       7      7573     7437
# 1     1                            Andhra Pradesh   14452   2023242  1994855
# 2     3                         Arunachal Pradesh     611     53474    52595
# 3     4                                     Assam    6457    593087   580911
# 4     5                                     Bihar      55    725765   716054
# 5     6                                Chandigarh      34     65124    64275
# 6     7                              Chhattisgarh     364   1004724   990803
# 7     8  Dadra and Nagar Haveli and Daman and Diu       2     10665    10659
# 8    10                                     Delhi     386   1438041  1412572
# 9    11                                       Goa     854    174560   170496
# 10   12                                   Gujarat     149    825527   815296
# 11   13                                   Haryana     622    770584   760276
# 12   14                          Himachal Pradesh    1682    214911   209611
# 13   15                         Jammu and Kashmir    1264    326159   320485
# 14   16                                 Jharkhand     129    347989   342727
# 15   17                                 Karnataka   17458   2956988  2902089
# 16   18                                    Kerala  237601   4253298  3993877
# 17   19                                    Ladakh      48     20593    20338
# 18   20                               Lakshadweep       4     10348    10293
# 19   21                            Madhya Pradesh     127    792281   781638
# 20   22                               Maharashtra   51465   6493698  6304336
# 21   23                                   Manipur    3168    115866   110896
# 22   24                                 Meghalaya    1924     77275    74016
# 23   25                                   Mizoram   11986     66910    54697
# 24   26                                  Nagaland     709     30435    29094
# 25   27                                    Odisha    6152   1012805   998591
# 26   28                                Puducherry     974    124311   121518
# 27   29                                    Punjab     320    600877   584110
# 28   30                                 Rajasthan      80    954149   945115
# 29   31                                    Sikkim     859     30330    29095
# 30   32                                Tamil Nadu   16205   2625778  2574518
# 31   34                                 Telangana    5476    660142   650778
# 32   33                                   Tripura     647     83414    81964
# 33   35                               Uttarakhand     371    343139   335379
# 34   36                             Uttar Pradesh     227   1709479  1686389
# 35   37                               West Bengal    8387   1553177  1526268
#
#      death  new_active  new_positive  new_cured  new_death state_code
# 0      129           9          7576       7438        129         35
# 1    13935       14510       2024603    1996143      13950         28
# 2      268         617         53551      52665        269         12
# 3     5719        6298        593514     581493       5723         18
# 4     9656          65        725784     716062       9657         10
# 5      815          31         65138      64292        815         04
# 6    13557         390       1004772     990825      13557         22
# 7        4           6         10669      10659          4         26
# 8    25083         414       1438082    1412585      25083         07
# 9     3210         856        174646     170578       3212         30
# 10   10082         151        825544     815311      10082         24
# 11    9686         607        770601     760308       9686         06
# 12    3618        1703        215074     209749       3622         02
# 13    4410        1251        326310     320648       4411         01
# 14    5133         139        348012     342740       5133         20
# 15   37441       17085       2958090    2903547      37458         29
# 16   21820      240037       4283494    4021456      22001         32
# 17     207          39         20593      20347        207         37
# 18      51           2         10349      10296         51         31
# 19   10516         137        792297     781644      10516         23
# 20  137897       51419       6497872    6308491     137962         27
# 21    1802        3164        116134     111165       1805         14
# 22    1335        1888         77471      74246       1337         17
# 23     227       12304         67971      55438        229         15
# 24     632         707         30485      29144        634         13
# 25    8062        6332       1013567     999165       8070         21
# 26    1819         986        124436     121631       1819         34
# 27   16447         319        600914     584146      16449         03
# 28    8954          82        954161     945125       8954         08
# 29     376         862         30384      29146        376         11
# 30   35055       16180       2627365    2576112      35073         33
# 31    3888        5497        660471     651085       3889         36
# 32     803         676         83478      81999        803         16
# 33    7389         349        343151     335413       7389         05
# 34   22863         214       1709494    1686417      22863         09
# 35   18522        8288       1553928    1527109      18531         19

# %%
df['active'].sum(axis = 0) 
# The total number of active cases in India is 2,22,526
# Out:
# 391256

# %%
df['positive'].sum(axis = 0) 
# The total number of positive cases in India are 10,466,595
# Out:
# 33096718

# %%
df['cured'].sum(axis = 0)
# The total number of cured cases in India is 10,092,909
# Out:
# 32264051

# %%
df['death'].sum(axis = 0)
# The total number of deaths in India are 1,51,160
# Out:
# 441411

# %%
df['new_active'].sum(axis = 0)
# The total number of new active cases are 2,16,558
# Out:
# 393614

# %%
df['new_positive'].sum(axis = 0)
# The total number of new positive cases are 10,479,179
# Out:
# 33139981

# %%
df['new_cured'].sum(axis = 0)
# The total number of new cured cases are 10,111,294
# Out:
# 32304618

# %%
df['new_death'].sum(axis = 0)
# The total number of new death cases are 1,51,327
# Out:
# 441749

# %% [markdown]
# ### Data Visualization

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum()
# Storing total cases in cases_df

# %%
cases_df
# Subset of original dataset
# Out:
# sno                                                           694
# state_name      Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                     391256
# positive                                                 33096718
# cured                                                    32264051
# death                                                      441411
# new_active                                                 393614
# new_positive                                             33139981
# new_cured                                                32304618
# new_death                                                  441749
# state_code      3528121810042226073024060201202932373123271417...
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns

# %%
cases_df
# Name of case types and their total number
# Out:
# active            391256
# positive        33096718
# cured           32264051
# death             441411
# new_active        393614
# new_positive    33139981
# new_cured       32304618
# new_death         441749
# dtype: object

# %%
my_data = [222526,10466595,10092909,151160]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# we have dropped columns like sno and statecode
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands       7      7573     7437    129           9
# 1               Andhra Pradesh   14452   2023242  1994855  13935       14510
# 2            Arunachal Pradesh     611     53474    52595    268         617
# 3                        Assam    6457    593087   580911   5719        6298
# 4                        Bihar      55    725765   716054   9656          65
#
#    new_positive  new_cured  new_death
# 0          7576       7438        129
# 1       2024603    1996143      13950
# 2         53551      52665        269
# 3        593514     581493       5723
# 4        725784     716062       9657

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands       7      7573     7437    129           9
# Andhra Pradesh                14452   2023242  1994855  13935       14510
# Arunachal Pradesh               611     53474    52595    268         617
# Assam                          6457    593087   580911   5719        6298
# Bihar                            55    725765   716054   9656          65
#
#                              new_positive  new_cured  new_death
# state_name
# Andaman and Nicobar Islands          7576       7438        129
# Andhra Pradesh                    2024603    1996143      13950
# Arunachal Pradesh                   53551      52665        269
# Assam                              593514     581493       5723
# Bihar                              725784     716062       9657

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <AxesSubplot:ylabel='state_name'>
